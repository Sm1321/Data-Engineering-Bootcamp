# %%
# %sql

CREATE TABLE customers (
    customer_id INT ,
    first_name VARCHAR(50),
    last_name VARCHAR(50),
    city VARCHAR(50),
    email VARCHAR(100)
);

# %%
# %sql
CREATE TABLE orders (
    order_id INT ,
    customer_id INT,
    order_date DATE,
    total_amount DECIMAL(10, 2)
);

# %%
# %sql
CREATE TABLE order_details (
    order_detail_id INT ,
    order_id INT,
    customer_id INT,
    product_id INT,
    product_name VARCHAR(100),
    category VARCHAR(50),
    quantity INT,
    price_each DECIMAL(10,2),
    order_date DATE
);

# %%
# %sql
INSERT INTO customers VALUES
(1, 'John', 'Doe', 'Delhi', 'john.doe@example.com'),
(2, 'Jane', 'Smith', 'Mumbai', 'jane.smith@example.com'),
(3, 'Raj', 'Kumar', 'Bangalore', 'raj.kumar@example.com'),
(4, 'Priya', 'Sharma', 'Hyderabad', 'priya.sharma@example.com'),
(5, 'Tom', 'Brown', 'Pune', 'tom.brown@example.com'),
(6, 'Sara', 'Ali', 'Chennai', 'sara.ali@example.com'),
(7, 'Vikram', 'Singh', 'Delhi', 'vikram.singh@example.com'),
(8, 'Neha', 'Patel', 'Mumbai', 'neha.patel@example.com'),
(9, 'David', 'Lee', 'Kolkata', 'david.lee@example.com'),
(10, 'Amit', 'Verma', 'Jaipur', 'amit.verma@example.com'),
(11, 'Emily', 'Clark', 'Delhi', 'emily.clark@example.com'),
(12, 'Ananya', 'Roy', 'Mumbai', 'ananya.roy@example.com'),
(13, 'Sam', 'Wilson', 'Pune', 'sam.wilson@example.com'),
(14, 'Pooja', 'Das', 'Hyderabad', 'pooja.das@example.com'),
(15, 'Arjun', 'Nair', 'Chennai', 'arjun.nair@example.com'),
(16, 'Kavita', 'Gupta', 'Bangalore', 'kavita.gupta@example.com'),
(17, 'Robert', 'King', 'Delhi', 'robert.king@example.com'),
(18, 'Meera', 'Joshi', 'Mumbai', 'meera.joshi@example.com'),
(19, 'Michael', 'Scott', 'Kolkata', 'michael.scott@example.com'),
(20, 'Ravi', 'Menon', 'Pune', 'ravi.menon@example.com'),
(21, 'Tina', 'Fernandez', 'Delhi', 'tina.fernandez@example.com'),
(22, 'Arvind', 'Singh', 'Hyderabad', 'arvind.singh@example.com'),
(23, 'Lucy', 'Adams', 'Chennai', 'lucy.adams@example.com'),
(24, 'Karan', 'Malhotra', 'Mumbai', 'karan.malhotra@example.com'),
(25, 'Sneha', 'Reddy', 'Pune', 'sneha.reddy@example.com'),
(26, 'George', 'Mason', 'Bangalore', 'george.mason@example.com'),
(27, 'Vishal', 'Kapoor', 'Kolkata', 'vishal.kapoor@example.com'),
(28, 'Emma', 'Watson', 'Delhi', 'emma.watson@example.com'),
(29, 'Siddharth', 'Jain', 'Hyderabad', 'siddharth.jain@example.com'),
(30, 'Olivia', 'Brown', 'Chennai', 'olivia.brown@example.com'),
(31, 'Nikhil', 'Arora', 'Mumbai', 'nikhil.arora@example.com'),
(32, 'Ayesha', 'Khan', 'Delhi', 'ayesha.khan@example.com'),
(33, 'Chris', 'Evans', 'Bangalore', 'chris.evans@example.com'),
(34, 'Ishita', 'Bhatt', 'Kolkata', 'ishita.bhatt@example.com'),
(35, 'Shyam', 'Patil', 'Pune', 'shyam.patil@example.com'),
(36, 'Sophia', 'Green', 'Chennai', 'sophia.green@example.com'),
(37, 'Harsh', 'Aggarwal', 'Hyderabad', 'harsh.aggarwal@example.com'),
(38, 'Liam', 'Martin', 'Delhi', 'liam.martin@example.com'),
(39, 'Diya', 'Saxena', 'Mumbai', 'diya.saxena@example.com'),
(40, 'Jason', 'Taylor', 'Kolkata', 'jason.taylor@example.com'),
(41, 'Ritika', 'Mehra', 'Pune', 'ritika.mehra@example.com'),
(42, 'Steve', 'Jobs', 'Bangalore', 'steve.jobs@example.com'),
(43, 'Alisha', 'Paul', 'Hyderabad', 'alisha.paul@example.com'),
(44, 'Dhruv', 'Singhania', 'Chennai', 'dhruv.singhania@example.com'),
(45, 'Rebecca', 'Lewis', 'Delhi', 'rebecca.lewis@example.com'),
(46, 'Naveen', 'Shetty', 'Mumbai', 'naveen.shetty@example.com'),
(47, 'Julia', 'Roberts', 'Pune', 'julia.roberts@example.com'),
(48, 'Parth', 'Desai', 'Hyderabad', 'parth.desai@example.com'),
(49, 'Nina', 'Shah', 'Chennai', 'nina.shah@example.com'),
(50, 'Aria', 'Gill', 'Bangalore', 'aria.gill@example.com');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>50</td><td>50</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO orders VALUES
(1001, 1, '2023-01-10', 1500.00),
(1002, 2, '2023-01-11', 2500.00),
(1003, 3, '2023-01-15', 500.00),
(1004, 1, '2023-02-01', 750.00),
(1005, 4, '2023-02-05', 2000.00),
(1006, 5, '2023-02-08', 1800.00),
(1007, 6, '2023-03-01', 2200.00),
(1008, 7, '2023-03-05', 3000.00),
(1009, 8, '2023-03-09', 1200.00),
(1010, 9, '2023-03-10', 900.00),
(1011, 10, '2023-03-12', 1900.00),
(1012, 11, '2023-03-15', 1500.00),
(1013, 12, '2023-03-18', 2400.00),
(1014, 13, '2023-03-20', 600.00),
(1015, 14, '2023-03-22', 3000.00),
(1016, 15, '2023-03-25', 2800.00),
(1017, 16, '2023-03-28', 3200.00),
(1018, 17, '2023-03-30', 500.00),
(1019, 18, '2023-04-01', 950.00),
(1020, 19, '2023-04-03', 1750.00),
(1021, 20, '2023-04-05', 2100.00),
(1022, 21, '2023-04-08', 1200.00),
(1023, 22, '2023-04-10', 1400.00),
(1024, 23, '2023-04-12', 800.00),
(1025, 24, '2023-04-14', 3300.00),
(1026, 25, '2023-04-16', 2400.00),
(1027, 26, '2023-04-18', 1800.00),
(1028, 27, '2023-04-20', 2000.00),
(1029, 28, '2023-04-22', 2200.00),
(1030, 29, '2023-04-24', 1950.00),
(1031, 30, '2023-04-26', 2600.00),
(1032, 31, '2023-04-28', 1550.00),
(1033, 32, '2023-05-01', 2700.00),
(1034, 33, '2023-05-03', 1000.00),
(1035, 34, '2023-05-05', 1900.00),
(1036, 35, '2023-05-07', 2100.00),
(1037, 36, '2023-05-09', 1100.00),
(1038, 37, '2023-05-11', 1250.00),
(1039, 38, '2023-05-13', 1850.00),
(1040, 39, '2023-05-15', 1400.00),
(1041, 40, '2023-05-17', 1750.00),
(1042, 41, '2023-05-19', 900.00),
(1043, 42, '2023-05-21', 2500.00),
(1044, 43, '2023-05-23', 3000.00),
(1045, 44, '2023-05-25', 2100.00),
(1046, 45, '2023-05-27', 2600.00),
(1047, 46, '2023-05-29', 2700.00),
(1048, 47, '2023-05-31', 2800.00),
(1049, 48, '2023-06-02', 1500.00),
(1050, 49, '2023-06-04', 1200.00),
(1051, 50, '2023-06-06', 800.00),
(1052, 1, '2023-06-08', 2000.00),
(1053, 2, '2023-06-10', 2300.00),
(1054, 3, '2023-06-12', 1400.00),
(1055, 4, '2023-06-14', 1750.00),
(1056, 5, '2023-06-16', 2600.00),
(1057, 6, '2023-06-18', 2100.00),
(1058, 7, '2023-06-20', 900.00),
(1059, 8, '2023-06-22', 3000.00),
(1060, 9, '2023-06-24', 1200.00),
(1061, 10, '2023-06-26', 1850.00),
(1062, 11, '2023-06-28', 1750.00),
(1063, 12, '2023-06-30', 1600.00),
(1064, 13, '2023-07-02', 950.00),
(1065, 14, '2023-07-04', 2100.00),
(1066, 15, '2023-07-06', 2500.00),
(1067, 16, '2023-07-08', 3000.00),
(1068, 17, '2023-07-10', 2700.00),
(1069, 18, '2023-07-12', 1500.00),
(1070, 19, '2023-07-14', 1400.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>70</td><td>70</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO order_details VALUES
(1, 1001, 1, 201, 'Laptop', 'Electronics', 1, 50000.00, '2023-01-10'),
(2, 1001, 1, 203, 'Headphones', 'Accessories', 2, 2000.00, '2023-01-10'),
(3, 1002, 2, 202, 'Smartphone', 'Electronics', 1, 30000.00, '2023-01-11'),
(4, 1003, 3, 205, 'Water Bottle', 'Kitchen', 3, 500.00, '2023-01-15'),
(5, 1004, 1, 208, 'Bluetooth Speaker', 'Electronics', 1, 3500.00, '2023-02-01'),
(6, 1005, 4, 204, 'Desk Chair', 'Furniture', 1, 4000.00, '2023-02-05'),
(7, 1006, 5, 207, 'Office Desk', 'Furniture', 1, 7000.00, '2023-02-08'),
(8, 1007, 6, 211, 'Tablet', 'Electronics', 2, 25000.00, '2023-03-01'),
(9, 1008, 7, 215, 'Gaming Chair', 'Furniture', 1, 15000.00, '2023-03-05'),
(10, 1009, 8, 209, 'Notebook', 'Stationery', 5, 200.00, '2023-03-09');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM ORDERS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>order_date</th><th>total_amount</th></tr></thead><tbody><tr><td>1001</td><td>1</td><td>2023-01-10</td><td>1500.00</td></tr><tr><td>1002</td><td>2</td><td>2023-01-11</td><td>2500.00</td></tr><tr><td>1003</td><td>3</td><td>2023-01-15</td><td>500.00</td></tr><tr><td>1004</td><td>1</td><td>2023-02-01</td><td>750.00</td></tr><tr><td>1005</td><td>4</td><td>2023-02-05</td><td>2000.00</td></tr><tr><td>1006</td><td>5</td><td>2023-02-08</td><td>1
td><td>Bangalore</td><td>chris.evans@example.com</td></tr><tr><td>34</td><td>Ishita</td><td>Bhatt</td><td>Kolkata</td><td>ishita.bhatt@example.com</td></tr><tr><td>35</td><td>Shyam</td><td>Patil</td><td>Pune</td><td>shyam.patil@example.com</td></tr><tr><td>36</td><td>Sophia</td><td>Green</td><td>Chennai</td><td>sophia.green@example.com</td></tr><tr><td>37</td><td>Harsh</td><td>Aggarwal</td><td>Hyderabad</td><td>harsh.aggarwal@example.com</td></tr><tr><td>38</td><td>Liam</td><td>Martin</td><td>Delhi</td><td>liam.martin@example.com</td></tr><tr><td>39</td><td>Diya</td><td>Saxena</td><td>Mumbai</td><td>diya.saxena@example.com</td></tr><tr><td>40</td><td>Jason</td><td>Taylor</td><td>Kolkata</td>< ...

# %%
# %sql 
-- List all the cusotmer orders with product details 
--INNER JOIN

SELECT c.customer_id,c.first_name, c.last_name,o.order_id, o.product_name, o.quantity
FROM  CUSTOMERS as c INNER JOIN ORDER_DETAILS as o
ON c.customer_id = o.customer_id ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>order_id</th><th>product_name</th><th>quantity</th></tr></thead><tbody><tr><td>1</td><td>John</td><td>Doe</td><td>1004</td><td>Bluetooth Speaker</td><td>1</td></tr><tr><td>2</td><td>Jane</td><td>Smith</td><td>1002</td><td>Smartphone</td><td>1</td></tr><tr><td>3</td><td>Raj</td><td>Kumar</td><td>1003</td><td>Water Bottle</td><td>3</td></tr><tr><td>4</td><td>Priya</td><td>Sharma</td><td>1005</td><td>Desk Chair</td><td>1</td></tr><tr><td>5</td><td>Tom</td><td>Brown</td><td>1006</td><td>Office Desk</td><td>1</td></tr><tr><td>6</td><td>Sara</td><td>Ali</td><td>1007</td><td>Tablet</td><td>2</td></tr><tr><td>7</td><td>Vikram</td><td>Singh</td><td>1008</td><td>Gaming Chair</td><td>1</td></tr><tr><td>8</td><td>Neha</td><td>Patel</td><td>1009</td><td>Notebook</td><td>5</td></tr><tr><td>1</td><td>John</td><td>Doe</td><td>1001</td><td>Headphones</td><td>2</td></tr><tr><td>1</td><td>John</td><td>Doe</td><td>1001</td><td>Laptop</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
--Full Breakdown : custoemrs,order, product_info

SELECT c.first_name,od.customer_id,od.product_name,od.quantity,od.order_id,o.customer_id,o.order_id,od.price_each
FROM ORDER_DETAILS as od INNER JOIN ORDERS as o
ON od.order_id = o.order_id
INNER JOIN CUSTOMERS as c ON c.customer_id=od.customer_id ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>customer_id</th><th>product_name</th><th>quantity</th><th>order_id</th><th>customer_id</th><th>order_id</th><th>price_each</th></tr></thead><tbody><tr><td>John</td><td>1</td><td>Laptop</td><td>1</td><td>1001</td><td>1</td><td>1001</td><td>50000.00</td></tr><tr><td>Jane</td><td>2</td><td>Smartphone</td><td>1</td><td>1002</td><td>2</td><td>1002</td><td>30000.00</td></tr><tr><td>Raj</td><td>3</td><td>Water Bottle</td><td>3</td><td>1003</td><td>3</td><td>1003</td><td>500.00</td></tr><tr><td>Priya</td><td>4</td><td>Desk Chair</td><td>1</td><td>1005</td><td>4</td><td>1005</td><td>4000.00</td></tr><tr><td>Tom</td><td>5</td><td>Office Desk</td><td>1</td><td>1006</td><td>5</td><td>1006</td><td>7000.00</td></tr><tr><td>Sara</td><td>6</td><td>Tablet</td><td>2</td><td>1007</td><td>6</td><td>1007</td><td>25000.00</td></tr><tr><td>Vikram</td><td>7</td><td>Gaming Chair</td><td>1</td><td>1008</td><td>7</td><td>1008</td><td>15000.00</td></tr><tr><td>Neha</td><td>8</td><td>Notebook</td><td>5</td><td>1009</td><td>8</td><td>1009</td><td>200.00</td></tr><tr><td>John</td><td>1</td><td>Bluetooth Speaker</td><td>1</td><td>1004</td><td>1</td><td>1004</td><td>3500.00</td></tr><tr><td>John</td><td>1</td><td>Headphones</td><td>2</td><td>1001</td><td>1</td><td>1001</td><td>2000.00</td></tr></tbody></table></div>

# %%
# %sql

SELECT 
od.order_id, c.first_name, od.product_name, od.quantity, od.price_each

 FROM ORDER_DETAILS as od 
 INNER JOIN  ORDERS as o ON od.order_id=o.order_id
 INNER JOIN CUSTOMERS as c ON o.customer_id=c.customer_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>first_name</th><th>product_name</th><th>quantity</th><th>price_each</th></tr></thead><tbody><tr><td>1001</td><td>John</td><td>Laptop</td><td>1</td><td>50000.00</td></tr><tr><td>1002</td><td>Jane</td><td>Smartphone</td><td>1</td><td>30000.00</td></tr><tr><td>1003</td><td>Raj</td><td>Water Bottle</td><td>3</td><td>500.00</td></tr><tr><td>1005</td><td>Priya</td><td>Desk Chair</td><td>1</td><td>4000.00</td></tr><tr><td>1006</td><td>Tom</td><td>Office Desk</td><td>1</td><td>7000.00</td></tr><tr><td>1007</td><td>Sara</td><td>Tablet</td><td>2</td><td>25000.00</td></tr><tr><td>1008</td><td>Vikram</td><td>Gaming Chair</td><td>1</td><td>15000.00</td></tr><tr><td>1009</td><td>Neha</td><td>Notebook</td><td>5</td><td>200.00</td></tr><tr><td>1004</td><td>John</td><td>Bluetooth Speaker</td><td>1</td><td>3500.00</td></tr><tr><td>1001</td><td>John</td><td>Headphones</td><td>2</td><td>2000.00</td></tr></tbody></table></div>

# %%
# %sql 
SELECT C.first_name,c.last_name,C.customer_id,od.order_date,od.category,od.order_id
FROM CUSTOMERS as C LEFT JOIN order_details as Od
ON C.customer_id = od.customer_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>customer_id</th><th>order_date</th><th>category</th><th>order_id</th></tr></thead><tbody><tr><td>John</td><td>Doe</td><td>1</td><td>2023-02-01</td><td>Electronics</td><td>1004</td></tr><tr><td>Jane</td><td>Smith</td><td>2</td><td>2023-01-11</td><td>Electronics</td><td>1002</td></tr><tr><td>Raj</td><td>Kumar</td><td>3</td><td>2023-01-15</td><td>Kitchen</td><td>1003</td></tr><tr><td>Priya</td><td>Sharma</td><td>4</td><td>2023-02-05</td><td>Furniture</td><td>1005</td></tr><tr><td>Tom</td><td>Brown</td><td>5</td><td>2023-02-08</td><td>Furniture</td><td>1006</td></tr><tr><td>Sara</td><td>Ali</td><td>6</td><td>2023-03-01</td><td>Electronics</td><td>1007</td></tr><tr><td>Vikram</td><td>Singh</td><td>7</td><td>2023-03-05</td><td>Furniture</td><td>1008</td></tr><tr><td>Neha</td><td>Patel</td><td>8</td><td>2023-03-09</td><td>Stationery</td><td>1009</td></tr><tr><td>David</td><td>Lee</td><td>9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>
# %%
# %sql 
--Idenify the Customers who has not palced any order and followup with them 

SELECT 
c.first_name,c.last_name
 FROM CUSTOMERS as c 
 LEFT JOIN ORDERS as o 
 ON c.customer_id = o.customer_id
 where o.order_id is  null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th></tr></thead><tbody></tbody></table></div>

# %%
   # %sql 

--show inactive and active customers 

SELECT 
c.first_name,c.last_name,o.order_id,o.order_date
 FROM ORDERS as o 
 RIGHT JOIN CUSTOMERS c ON c.customer_id=o.customer_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>order_id</th><th>order_date</th></tr></thead><tbody><tr><td>John</td><td>Doe</td><td>1052</td><td>2023-06-08</td></tr><tr><td>Jane</td><td>Smith</td><td>1053</td><td>2023-06-10</td></tr><tr><td>Raj</td><td>Kumar</td><td>1054</td><td>2023-06-12</td></tr><tr><td>Priya</td><td>Sharma</td><td>1055</td><td>2023-06-14</td></tr><tr><td>Tom</td><td>Brown</td><td>1056</td><td>2023-06-16</td></tr><tr><td>Sara</td><td>Ali</td><td>1057</td><td>2023-06-18</td></tr><tr><td>Vikram</td><td>Singh</td><td>1058</td><td>2023-06-20</td></tr><tr><td>Neha</td><td>Patel</td><td>1059</td><td>2023-06-22</td></tr><tr><td>David</td><td>Lee</td><td>1060</td><td>2023-06-24</td></tr><tr><td>Amit</td><td>Verma</td><td>1061</td><td>2023-06-26</td></tr><tr><td>Emily</td><td>Clark</td><td>1062</td><td>2023-06-28</td></tr><tr><td>Ananya</td><td>Roy</td><td>1063</td><td>2023-06-30</td></tr><tr><td>Sam</td><td>Wilson</td><td>1064</td><td>2023-07-02</td></tr><tr><td>Pooja</td><td>Das</td><td>1065</td><td>2023-07-04</td></tr><tr><td>Arjun</td><td>Nair</td><td>1066</td><td>2023-07-06</td></tr><tr><td>Kavita</td><td>Gupta</td><td>1067</td><td>2023-07-08</td></tr><tr><td>Robert</td><td>King</td><td>1068</td><td>2023-07-10</td></tr><tr><td>Meera</td><td>Joshi</td><td>1069</td><td>2023-07-12</td></tr><tr><td>Michael</td><td>Scott</td><td>1070</td><td>2023-07-14</td></tr><tr><td>Ravi</td><td>Menon</td><td>1021</td><td>2023-04-05</td></tr><tr><td>Tina</td><td>Fernandez</td><td>1022</td><td>2023-04-08</td></tr><tr><td>Arvind</td><td>Singh</td><td>1023</td><td>2023-04-10</td></tr><tr><td>Lucy</td><td>Adams</td><td>1024</td><td>2023-04-12</td></tr><tr><td>Karan</td><td>Malhotra</td><td>1025</td><td>2023-04-14</td></tr><tr><td>Sneha</td><td>Reddy</td><td>1026</td><td>2023-04-16</td></tr><tr><td>George</td><td>Mason</td><td>1027</td><td>2023-04-18</td></tr><tr><td>Vishal</td><td>Kapoor</td><td>1028</td><td>2023-04-20</td></tr><tr><td>Emma</td><td>Watson</td
r><tr><td>48</td><td>Parth</td><td>1049</td><td>2023-06-02</td></tr><tr><td>49</td><td>Nina</td><td>1050</td><td>2023-06-04</td></tr><tr><td>50</td><td>Aria</td><td>1051</td><td>2023-06-06</td></tr><tr><td>1</td><td>John</td><td>1004</td><td>2023-02-01</td></tr><tr><td>2</td><td>Jane</td><td>1002</td><td>2023-01-11</td></tr><tr><td>3</td><td>Raj</td><td>1003</td><td>2023-01-15</td></tr><tr><td>4</td><td>Priya</td><td>1005</td><td>2023-02-05</td></tr><tr><td>5</td><td>Tom</td><td>1006</td><td>2023-02-08</td></tr><tr><td>6</td><td>Sara</td><td>1007</td><td>2023-03-01</td></tr><tr><td>7</td><td>Vikram</td><td>1008</td><td>2023-03-05</td></tr><tr><td>8</td><td>Neha</td><td>1009</td><td>20 ...

# %%
# %sql
CREATE TABLE emp (
    emp_id INT ,
    first_name VARCHAR(50),
    last_name VARCHAR(50),
    manager_id INT,
    department VARCHAR(50)
);

# %%
# %sql
INSERT INTO emp VALUES
(1, 'Alice', 'Johnson', NULL, 'Management'),
(2, 'Bob', 'Smith', 1, 'Sales'),
(3, 'Carol', 'Taylor', 1, 'Sales'),
(4, 'David', 'Brown', 2, 'Sales'),
(5, 'Eva', 'Davis', 2, 'Sales'),
(6, 'Frank', 'Miller', 1, 'Engineering'),
(7, 'Grace', 'Wilson', 6, 'Engineering'),
(8, 'Henry', 'Moore', 6, 'Engineering'),
(9, 'Ivy', 'Clark', 3, 'Sales'),
(10, 'Jack', 'Hall', 3, 'Sales');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %%
# %sql

-- Employee + Their Manager
SELECT distinct e1.first_name AS employee, e2.first_name AS manager, e1.department
FROM emp e1
LEFT JOIN emp e2 ON e1.manager_id = e2.emp_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee</th><th>manager</th><th>department</th></tr></thead><tbody><tr><td>David</td><td>Bob</td><td>Sales</td></tr><tr><td>Henry</td><td>Frank</td><td>Engineering</td></tr><tr><td>Ivy</td><td>Carol</td><td>Sales</td></tr><tr><td>Eva</td><td>Bob</td><td>Sales</td></tr><tr><td>Bob</td><td>Alice</td><td>Sales</td></tr><tr><td>Frank</td><td>Alice</td><td>Engineering</td></tr><tr><td>Grace</td><td>Frank</td><td>Engineering</td></tr><tr><td>Carol</td><td>Alice</td><td>Sales</td></tr><tr><td>Jack</td><td>Carol</td><td>Sales</td></tr><tr><td>Alice</td><td>null</td><td>Management</td></tr></tbody></table></div>

# %%
# %sql

--  Full audit of customers + orders (matched or not).
 SELECT c.first_name, o.order_id, od.product_name
FROM customers c
FULL OUTER JOIN orders o ON c.customer_id = o.customer_id
FULL OUTER JOIN order_details od ON o.order_id = od.order_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th
r><tr><td>Ayesha</td><td>1033</td><td>null</td></tr><tr><td>Karan</td><td>1025</td><td>null</td></tr><tr><td>Sam</td><td>1064</td><td>null</td></tr><tr><td>David</td><td>1010</td><td>null</td></tr><tr><td>Emma</td><td>1029</td><td>null</td></tr><tr><td>Vikram</td><td>1008</td><td>Gaming Chair</td></tr><tr><td>John</td><td>1001</td><td>Headphones</td></tr><tr><td>Liam</td><td>1039</td><td>null</td></tr><tr><td>Arjun</td><td>1066</td><td>null</td></tr><tr><td>Amit</td><td>1061</td><td>null</td></tr><tr><td>John</td><td>1001</td><td>Laptop</td></tr></tbody></table></div>

# %%
# %sql
-- Get list of all unique customer cities + unique product categories.

SELECT  city AS item FROM customers
UNION
SELECT  category FROM order_details;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item</th></tr></thead><tbody><tr><td>Kolkata</td></tr><tr><td>Bangalore</td></tr><tr><td>Chennai</td></tr><tr><td>Jaipur</td></tr><tr><td>Delhi</td></tr><tr><td>Mumbai</td></tr><tr><td>Pune</td></tr><tr><td>Hyderabad</td></tr><tr><td>Accessories</td></tr><tr><td>Furniture</td></tr><tr><td>Stationery</td></tr><tr><td>Kitchen</td></tr><tr><td>Electronics</td></tr></tbody></table></div>

# %%
# %sql
-- Get list of all unique customer cities + unique product categories.(WITH DUPLICATES)

SELECT DISTINCT city AS item FROM customers
UNION ALL 
SELECT DISTINCT category FROM order_details;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item</th></tr></thead><tbody><tr><td>Kolkata</td></tr><tr><td>Bangalore</td></tr><tr><td>Chennai</td></tr><tr><td>Jaipur</td></tr><tr><td>Delhi</td></tr><tr><td>Mumbai</td></tr><tr><td>Pune</td></tr><tr><td>Hyderabad</td></tr><tr><td>Accessories</td></tr><tr><td>Furniture</td></tr><tr><td>Stationery</td></tr><tr><td>Kitchen</td></tr><tr><td>Electronics</td></tr></tbody></table></div>

# %%
# %sql 
-- Top 3 Customers by Spend
SELECT 
c.first_name, c.last_name, SUM(od.quantity * od.price_each) AS total_spent
FROM customers c 
INNER JOIN orders o ON c.customer_id = o.customer_id
INNER JOIN Order_details od on o.order_id = od.order_id
GROUP BY c.customer_id,c.first_name, c.last_name
ORDER BY total_spent DESC
LIMIT 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>total_spent</th></tr></thead><tbody><tr><td>John</td><td>Doe</td><td>57500.00</td></tr><tr><td>Sara</td><td>Ali</td><td>50000.00</td></tr><tr><td>Jane</td><td>Smith</td><td>30000.00</td></tr></tbody></table></div>

# %%
# %sql 
-- Top 3 Customers by Spend
SELECT 
c.first_name, c.last_name, SUM(od.quantity * od.price_each) AS total_spent
FROM customers c 
INNER JOIN orders o ON c.customer_id = o.customer_id
INNER JOIN Order_details od on o.order_id = od.order_id
GROUP BY c.customer_id,c.first_name, c.last_name
ORDER BY total_spent DESC
LIMIT 3 OFFSET 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>total_spent</th></tr></thead><tbody><tr><td>Jane</td><td>Smith</td><td>30000.00</td></tr><tr><td>Vikram</td><td>Singh</td><td>15000.00</td></tr><tr><td>Tom</td><td>Brown</td><td>7000.00</td></tr></tbody></table></div>
